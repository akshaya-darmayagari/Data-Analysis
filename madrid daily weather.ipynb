# %% [markdown]
# ### Goal:
# ## Explore the Madrid Daily Weather 1997-2015 dataset, clean data, perform analysis, and visualize results using NumPy, Pandas, Matplotlib, and Seaborn.

# %% [markdown]
# ### 1. Why This Project?
#
# #### 1.Learn data cleaning with Pandas.
#
# #### 2.Use NumPy for calculations (mean, median, etc.).
#
# #### 3.Visualize trends using Matplotlib and Seaborn.
#
# #### 4.Understand the relationship between student features (Gender, Parental Education, Test Preparation) and performance

# %% [markdown]
# ### 2. Import Libraries

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ### 3. Load Dataset

# %%
df = pd.read_csv("Madrid Daily Weather 1997-2015.csv")
df.head()
# Out:
#           CET  Max TemperatureC  Mean TemperatureC  Min TemperatureC  \
# 0  1997-01-01               7.0                4.0               2.0
# 1  1997-01-02               7.0                3.0               0.0
# 2  1997-01-03               5.0                3.0               2.0
# 3  1997-01-04               7.0                3.0              -1.0
# 4  1997-01-05               2.0                0.0              -1.0
#
#    Dew PointC  MeanDew PointC  Min DewpointC  Max Humidity   Mean Humidity  \
# 0         5.0             3.0            2.0         100.0            95.0
# 1         6.0             3.0            0.0         100.0            92.0
# 2         5.0             1.0           -1.0         100.0            85.0
# 3        -2.0            -3.0           -4.0          86.0            63.0
# 4         2.0             0.0           -3.0         100.0            95.0
#
#     Min Humidity  ...   Max VisibilityKm   Mean VisibilityKm  \
# ...

# %% [markdown]
# ### 4. Explore Data

# %%
print("Shape:", df.shape)
print(df.info())
print(df.isnull().sum())
print(df.describe())
# Out:
# Shape: (6812, 23)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6812 entries, 0 to 6811
# Data columns (total 23 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   CET                          6812 non-null   object
#  1   Max TemperatureC             6810 non-null   float64
#  2   Mean TemperatureC            6809 non-null   float64
#  3   Min TemperatureC             6810 non-null   float64
#  4   Dew PointC                   6810 non-null   float64
#  5   MeanDew PointC               6810 non-null   float64
#  6   Min DewpointC                6810 non-null   float64
#  7   Max Humidity                 6810 non-null   float64
#  8    Mean Humidity               6810 non-null   float64
#  9    Min Humidity                6810 non-null   float64
#  10   Max Sea Level PressurehPa   6812 non-null   int64
#  11   Mean Sea Level PressurehPa  6812 non-null   int64
# ...

# %%
print(df.columns)
# Out:
# Index(['CET', 'Max TemperatureC', 'Mean TemperatureC', 'Min TemperatureC',
#        'Dew PointC', 'MeanDew PointC', 'Min DewpointC', 'Max Humidity',
#        ' Mean Humidity', ' Min Humidity', ' Max Sea Level PressurehPa',
#        ' Mean Sea Level PressurehPa', ' Min Sea Level PressurehPa',
#        ' Max VisibilityKm', ' Mean VisibilityKm', ' Min VisibilitykM',
#        ' Max Wind SpeedKm/h', ' Mean Wind SpeedKm/h', ' Max Gust SpeedKm/h',
#        'Precipitationmm', ' CloudCover', ' Events', 'WindDirDegrees'],
#       dtype='object')

# %% [markdown]
# ### Insights:
#
# 1.The dataset has 6812 daily records spanning multiple years, with 23 attributes including temperature, humidity, wind, visibility, pressure, precipitation, and events.
#
# 2.Max TemperatureC ranges up to 32°C, Min TemperatureC can go as low as -1°C, and Mean TemperatureC averages around 15–16°C, showing seasonal variation.
#
# 3.Humidity varies widely: Max Humidity reaches 103%, Min Humidity can be 0%, and Mean Humidity is around 52%, indicating moderately humid conditions on average.
#
# 4.Visibility is mostly high (Mean around 10–15 km), but has missing values for 940 days, suggesting some incomplete observations.
#
# 5.Wind and precipitation extremes exist: Max Wind Speed goes up to 360 km/h (likely outliers), Max Gust Speed is missing for half the data, and Precipitation mostly ranges from 0–8 mm, indicating Madrid mostly experiences light or no precipitation.

# %% [markdown]
# ### 6. Analysis with NumPy & Pandas

# %%
# Remove leading/trailing spaces from all column names
df.columns = df.columns.str.strip()

import numpy as np

# Average temperatures
avg_max_temp = np.mean(df['Max TemperatureC'])
avg_mean_temp = np.mean(df['Mean TemperatureC'])
avg_min_temp = np.mean(df['Min TemperatureC'])
print("Average Max Temperature (°C):", avg_max_temp)
print("Average Mean Temperature (°C):", avg_mean_temp)
print("Average Min Temperature (°C):", avg_min_temp)

# Average humidity
avg_max_humidity = np.mean(df['Max Humidity'])
avg_mean_humidity = np.mean(df['Mean Humidity'])
avg_min_humidity = np.mean(df['Min Humidity'])
print("Average Max Humidity (%):", avg_max_humidity)
print("Average Mean Humidity (%):", avg_mean_humidity)
print("Average Min Humidity (%):", avg_min_humidity)

# Average wind speed
avg_wind_speed = np.mean(df['Mean Wind SpeedKm/h'])
print("Average Wind Speed (Km/h):", avg_wind_speed)
# Out:
# Average Max Temperature (°C): 21.03964757709251
# Average Mean Temperature (°C): 14.658687031869585
# Average Min Temperature (°C): 8.640528634361234
# Average Max Humidity (%): 81.13935389133627
# Average Mean Humidity (%): 57.97136563876652
# Average Min Humidity (%): 34.72936857562408
# Average Wind Speed (Km/h): 9.170728126834996

# %% [markdown]
# ### Insights:
#
# 1.The average Max Temperature is around X°C and the average Min Temperature is around Y°C, showing that Madrid experiences moderate daily temperatures.
#
# 2.Average humidity is about Z%, indicating a generally moderate climate with occasional very dry or very humid days.
#
# 3.The average wind speed is around W Km/h, suggesting mild to moderate wind conditions on most days.

# %% [markdown]
# ### 7. Visualization with Matplotlib

# %%
# Ensure CET is datetime
df['CET'] = pd.to_datetime(df['CET'])

# Extract month
df['Month'] = df['CET'].dt.month

# Average Max Temperature by Month
avg_max_temp_by_month = df.groupby('Month')['Max TemperatureC'].mean()

# Bar chart
months = avg_max_temp_by_month.index
temps = avg_max_temp_by_month.values

plt.bar(months, temps, color='skyblue')
plt.title("Average Max Temperature by Month")
plt.xlabel("Month")
plt.ylabel("Average Max Temperature (°C)")
plt.show()

# %% [markdown]
# ### Insights
#
# 1.The highest average temperatures occur in July and August, reflecting the peak of summer in Madrid.
#
# 2.The lowest average temperatures occur in January and February, showing the cold winter months.

# %%
df['CET'] = pd.to_datetime(df['CET'])

# Extract month
df['Month'] = df['CET'].dt.month

# Average Max Temperature by Month
avg_max_temp_by_month = df.groupby('Month')['Max TemperatureC'].mean()

# Line plot
plt.plot(avg_max_temp_by_month.index, avg_max_temp_by_month.values, marker='o', color='orange')
plt.title("Average Max Temperature by Month")
plt.xlabel("Month")
plt.ylabel("Average Max Temperature (°C)")
plt.xticks(range(1,13))  # Show all months on x-axis
plt.show()

# %% [markdown]
# ### Insights
#
# 1.Temperatures gradually increase from January to July and then decrease towards December, forming a clear seasonal pattern.
#
# 2.The warmest months are July and August, while January and December are the coldest, indicating typical Mediterranean climate trends.

# %% [markdown]
# ### 8. Visualization with Seaborn

# %%
sns.histplot(df['Max TemperatureC'], bins=20, kde=True, color='skyblue')
plt.title("Distribution of Max Temperature (°C)")
plt.xlabel("Max Temperature (°C)")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ### Insights
#
# 1.Most days in Madrid have moderate temperatures, with a peak around 15–25°C, reflecting mild weather for most of the year.
#
# 2.Very few days are extremely cold (<0°C) or extremely hot (>35°C), showing that extreme temperatures are rare.

# %%
# Create Temperature Category
df['Temp Category'] = df['Max TemperatureC'].apply(lambda x: 'Hot (>=25°C)' if x >= 25 else 'Cold (<25°C)')

# Extract Month
df['Month'] = df['CET'].dt.month

# Countplot of Temperature Category by Month
plt.figure(figsize=(12,6))
sns.countplot(x='Month', hue='Temp Category', data=df, palette='coolwarm')
plt.title("Count of Hot and Cold Days by Month")
plt.xlabel("Month")
plt.ylabel("Number of Days")
plt.show()

# %% [markdown]
# ### Insights
#
# 1.OThe number of Hot days increases during summer months (June–August) and decreases during winter months (December–February).
#
# 2.Most winter months have predominantly Cold days, showing the seasonal effect on Madrid’s daily maximum temperatures.

# %%
df['Month'] = df['CET'].dt.month

# Boxplot of Max Temperature by Month
plt.figure(figsize=(12,6))
sns.boxplot(x='Month', y='Max TemperatureC', data=df, palette='coolwarm')
plt.title("Max Temperature Distribution by Month")
plt.xlabel("Month")
plt.ylabel("Max Temperature (°C)")
plt.show()
# Out:
# C:\Users\aksha\AppData\Local\Temp\ipykernel_5084\1843119878.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Month', y='Max TemperatureC', data=df, palette='coolwarm')

# %% [markdown]
# ### Insights
#
# 1.Summer months (June–August) have higher median temperatures and a wider spread, showing hot days and occasional extreme highs.
#
# 2.Winter months (December–February) have lower median temperatures with fewer extreme highs, indicating a cooler and more stable temperature range.

# %%
df['Temp Category'] = df['Max TemperatureC'].apply(lambda x: 'Hot (>=25°C)' if x >= 25 else 'Cold (<25°C)')

# Select numeric features for pairplot
numeric_features = ['Max TemperatureC', 'Mean TemperatureC', 'Min TemperatureC', 'Mean Humidity']

# Pairplot with Temp Category as hue
sns.pairplot(df[numeric_features + ['Temp Category']], hue='Temp Category', palette='coolwarm')
plt.show()

# %% [markdown]
# ### Insights
#
# 1.Hot days usually have higher max, mean, and min temperatures, and the points for Hot and Cold days are clearly separated.
#
# 2.There may be a negative correlation between temperature and humidity, showing that hotter days tend to have lower mean humidity.

# %%
numeric_features = ['Max TemperatureC', 'Mean TemperatureC', 'Min TemperatureC', 
                    'Mean Humidity', 'Max Wind SpeedKm/h']

# Compute correlation
corr = df[numeric_features].corr()

# Heatmap
plt.figure(figsize=(8,6))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap of Weather Features")
plt.show()

# %% [markdown]
# ### Insights
#
# 1.Max, Mean, and Min Temperatures are strongly positively correlated, as expected.
#
# 2.Temperature and Mean Humidity show a slight negative correlation, suggesting hotter days tend to be less humid.
#
# 3.Wind speed appears largely independent of temperature and humidity, with low correlation values.
